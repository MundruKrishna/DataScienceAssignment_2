# %% [markdown]
# # Date Night Movie
#
# #### Grading:
#
#
# - Code: 6.5 pts
# - Comments: .5pts
# - Markdown Documentation: .5pts

# %% [markdown]
# In this assignment we are going to use pandas to figure out - What's the best **date-night movie**?
#
# This assignment is going to use
# - Joining
# - Groupby
# - Sorting

# %%
import os
import pandas as pd
import random as rd

# %% [markdown]
# ##### Read in the movie data: `pd.read_table`

# %%
def get_movie_data():
    
    '''
    Function to read in movie related data
    
    Parameters
    ----------
    None
    
    Returns
    -------
    users: pd.DataFrame containing user data
    ratings: pd.DataFrame containing rating data
    movies: pd.DataFrame containing movie data
    '''
    
    unames = ['user_id','gender','age','occupation','zip']
    users = pd.read_csv(os.path.join('../data','users.dat'), 
                          sep='::', header=None, names=unames)
    
    rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
    ratings = pd.read_csv(os.path.join('../data', 'ratings.dat'), 
                            sep='::', header=None, names=rnames)
    
    mnames = ['movie_id', 'title','genres']
    movies = pd.read_csv(os.path.join('../data', 'movies.dat'), 
                           sep='::', engine='python',header=None, names=mnames)

    return users, ratings, movies

# %%
users, ratings, movies = get_movie_data()

# %%
users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ##### Clean up the `movies`
#
# - Get the `year`
# - Shorten the `title`

# %% [markdown]
# *Let us calculate mean rating and total number of ratings which helps us to find how movies are being rated*

# %%
movies["mean_rating"] = ""
movies["count_rating"] = ""
for i in range(2872):
    row1=movies.movie_id.iloc[i]
    count = ratings["movie_id"].astype(int) == row1
    movies["mean_rating"][i] = round(mulcount, 2)
    mulcount = ratings[condn]["rating"].mean()
    movies["count_rating"][i] = ratings[count]["rating"].count()
    pd.options.mode.chained_assignment = None


movies.head()
# Out:
#    movie_id                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#
#   mean_rating count_rating
# 0        3.78         2077
# 1        3.78          701
# 2        3.78          478
# 3        3.78          170
# 4        3.78          296

# %% [markdown]
# *Lets us extract the year of the movies from the Movies data set and add it into the table and also add only title of the movie into an another row as only title*

# %%
fulltitle = movies.title.str.extract('(.*) \(([0-9]+)\)')
fulltitle.apply(lambda x:x[0] if len(x) > 0 else None)
fulltitle.apply(lambda x: x[0][:40] if len(x) > 0 else None)
movies['year'] = fulltitle[1]
movies['titleonly'] = fulltitle[0]
movies
# Out:
#       movie_id                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 3878      3948             Meet the Parents (2000)
# 3879      3949          Requiem for a Dream (2000)
# 3880      3950                    Tigerland (2000)
# 3881      3951             Two Family House (2000)
# 3882      3952               Contender, The (2000)
#
#                             genres mean_rating count_rating  year  \
# 0      Animation|Children's|Comedy        3.78         2077  1995
# 1     Adventure|Children's|Fantasy        3.78          701  1995
# 2                   Comedy|Romance        3.78          478  1995
# 3                     Comedy|Drama        3.78          170  1995
# 4                           Comedy        3.78          296  1995
# ...                            ...         ...          ...   ...
# 3878                        Comedy                           2000
# 3879                         Drama                           2000
# 3880                         Drama                           2000
# 3881                         Drama                           2000
# 3882                Drama|Thriller                           2000
#
#                         titleonly
# 0                       Toy Story
# 1                         Jumanji
# 2                Grumpier Old Men
# 3               Waiting to Exhale
# 4     Father of the Bride Part II
# ...                           ...
# 3878             Meet the Parents
# 3879          Requiem for a Dream
# 3880                    Tigerland
# 3881             Two Family House
# 3882               Contender, The
#
# [3883 rows x 7 columns]

# %% [markdown]
# *Now let us assign the first part of the full title which is year*
# *Second part can be assigned to only title*

# %%
movies['year'] = fulltitle[1]
movies['titleonly'] = fulltitle[0]

# %%
movies.head()
# Out:
#    movie_id                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#
#   mean_rating count_rating  year                    titleonly
# 0        3.78         2077  1995                    Toy Story
# 1        3.78          701  1995                      Jumanji
# 2        3.78          478  1995             Grumpier Old Men
# 3        3.78          170  1995            Waiting to Exhale
# 4        3.78          296  1995  Father of the Bride Part II

# %% [markdown]
# ##### Join the tables with `pd.merge` (1 pts)

# %% [markdown]
# *Let us join the two tables first which are users and movies*

# %%
movieRatings = pd.merge(movies,ratings)
movieRatings
# Out:
#          movie_id                  title                       genres  \
# 0               1       Toy Story (1995)  Animation|Children's|Comedy
# 1               1       Toy Story (1995)  Animation|Children's|Comedy
# 2               1       Toy Story (1995)  Animation|Children's|Comedy
# 3               1       Toy Story (1995)  Animation|Children's|Comedy
# 4               1       Toy Story (1995)  Animation|Children's|Comedy
# ...           ...                    ...                          ...
# 1000204      3952  Contender, The (2000)               Drama|Thriller
# 1000205      3952  Contender, The (2000)               Drama|Thriller
# 1000206      3952  Contender, The (2000)               Drama|Thriller
# 1000207      3952  Contender, The (2000)               Drama|Thriller
# 1000208      3952  Contender, The (2000)               Drama|Thriller
#
#         mean_rating count_rating  year       titleonly  user_id  rating  \
# 0              3.78         2077  1995       Toy Story        1       5
# 1              3.78         2077  1995       Toy Story        6       4
# 2              3.78         2077  1995       Toy Story        8       4
# 3              3.78         2077  1995       Toy Story        9       5
# 4              3.78         2077  1995       Toy Story       10       5
# ...             ...          ...   ...             ...      ...     ...
# 1000204                           2000  Contender, The     5812       4
# 1000205                           2000  Contender, The     5831       3
# 1000206                           2000  Contender, The     5837       4
# 1000207                           2000  Contender, The     5927       1
# 1000208                           2000  Contender, The     5998       4
#
#           timestamp
# 0         978824268
# 1         978237008
# 2         978233496
# 3         978225952
# 4         978226474
# ...             ...
# 1000204   992072099
# 1000205   986223125
# 1000206  1011902656
# 1000207   979852537
# 1000208  1001781044
#
# [1000209 rows x 10 columns]

# %% [markdown]
# *Let us again join the two tables the one which is already merged and the user details table*

# %%
UserRatingsMovies=pd.merge(ratingsMovies,users)
UserRatingsMovies
# Out:
#          movie_id                                      title  \
# 0               1                           Toy Story (1995)
# 1              48                          Pocahontas (1995)
# 2             150                           Apollo 13 (1995)
# 3             260  Star Wars: Episode IV - A New Hope (1977)
# 4             527                    Schindler's List (1993)
# ...           ...                                        ...
# 1000204      3513                 Rules of Engagement (2000)
# 1000205      3535                     American Psycho (2000)
# 1000206      3536                   Keeping the Faith (2000)
# 1000207      3555                               U-571 (2000)
# 1000208      3578                           Gladiator (2000)
#
#                                        genres mean_rating count_rating  year  \
# 0                 Animation|Children's|Comedy        3.78         2077  1995
# 1        Animation|Children's|Musical|Romance        3.78          382  1995
# 2                                       Drama        3.78         1251  1995
# 3             Action|Adventure|Fantasy|Sci-Fi        3.78         2991  1977
# 4                                   Drama|War        3.78         2304  1993
# ...                                       ...         ...          ...   ...
# 1000204                        Drama|Thriller        3.78          420  2000
# 1000205                Comedy|Horror|Thriller        3.78          630  2000
# 1000206                        Comedy|Romance        3.78          489  2000
# 1000207                       Action|Thriller        3.78          908  2000
# 1000208                          Action|Drama        3.78         1924  2000
#
#                                   titleonly  user_id  rating  timestamp  \
# 0                                 Toy Story        1       5  978824268
# 1                                Pocahontas        1       5  978824351
# 2                                 Apollo 13        1       5  978301777
# 3        Star Wars: Episode IV - A New Hope        1       4  978300760
# 4                          Schindler's List        1       5  978824195
# ...                                     ...      ...     ...        ...
# 1000204                 Rules of Engagement     5727       4  958489970
# 1000205                     American Psycho     5727       2  958489970
# 1000206                   Keeping the Faith     5727       5  958489902
# 1000207                               U-571     5727       3  958490699
# 1000208                           Gladiator     5727       5  958490171
#
#         gender  age  occupation    zip
# 0            F    1          10  48067
# 1            F    1          10  48067
# 2            F    1          10  48067
# 3            F    1          10  48067
# 4            F    1          10  48067
# ...        ...  ...         ...    ...
# 1000204      M   25           4  92843
# 1000205      M   25           4  92843
# 1000206      M   25           4  92843
# 1000207      M   25           4  92843
# 1000208      M   25           4  92843
#
# [1000209 rows x 14 columns]

# %% [markdown]
# ##### Task 2 : Now lets find the highest rated move

# %% [markdown]
# *By using sort function we will be able to get the most liked movie and found as shown below*

# %%
highestRated = mergeall.groupby('titleonly').size().sort_values(ascending=False)
highestRated.head()
# Out:
# titleonly
# American Beauty                                   3428
# Star Wars: Episode IV - A New Hope                2991
# Star Wars: Episode V - The Empire Strikes Back    2990
# Star Wars: Episode VI - Return of the Jedi        2883
# Jurassic Park                                     2672
# dtype: int64

# %% [markdown]
# *Here We are taking two users randomly using randint and getting all their data which is already calculated. This data again can be used to find the most liked movie by both of them*

# %%
indiv1=rd.randint(1, 200)
temp1 = mergeall["user_id"].astype(int) == indiv1
rdInd1 = mergeall[temp1]
rdInd1 = rdInd1.sort_values(by = ['mean_rating', 'mean_rating'])
rdInd1.tail()
# Out:
#         movie_id                         title            genres mean_rating  \
# 972197      2966    Straight Story, The (1999)             Drama        3.78
# 972198      3007         American Movie (1999)       Documentary        3.78
# 972199      3448  Good Morning, Vietnam (1987)  Comedy|Drama|War        3.78
# 972200      3578              Gladiator (2000)      Action|Drama        3.78
# 972201      3753           Patriot, The (2000)  Action|Drama|War        3.78
#
#        count_rating  year              titleonly  user_id  rating  timestamp  \
# 972197          429  1999    Straight Story, The      171       4  977166419
# 972198          295  1999         American Movie      171       3  977167008
# 972199         1082  1987  Good Morning, Vietnam      171       4  977166262
# 972200         1924  2000              Gladiator      171       4  977166458
# 972201         1240  2000           Patriot, The      171       3  977166458
#
#        gender  age  occupation    zip
# 972197      F   50          17  55441
# 972198      F   50          17  55441
# 972199      F   50          17  55441
# 972200      F   50          17  55441
# 972201      F   50          17  55441

# %%
indiv2=rd.randint(500, 1000)
temp2 = mergeall["user_id"].astype(int) == indiv2
rdInd2 = mergeall[temp2]
rdInd2 = rdInd2.sort_values(by = ['mean_rating', 'count_rating'])
rdInd2.tail()
# Out:
#         movie_id                                      title  \
# 955090      2987            Who Framed Roger Rabbit? (1988)
# 955066       318           Shawshank Redemption, The (1994)
# 955070      1617                   L.A. Confidential (1997)
# 955063       110                          Braveheart (1995)
# 955065       260  Star Wars: Episode IV - A New Hope (1977)
#
#                                   genres mean_rating count_rating  year  \
# 955090     Adventure|Animation|Film-Noir        3.78         1799  1988
# 955066                             Drama        3.78         2227  1994
# 955070  Crime|Film-Noir|Mystery|Thriller        3.78         2288  1997
# 955063                  Action|Drama|War        3.78         2443  1995
# 955065   Action|Adventure|Fantasy|Sci-Fi        3.78         2991  1977
#
#                                  titleonly  user_id  rating  timestamp gender  \
# 955090            Who Framed Roger Rabbit?      784       5  975430595      M
# 955066           Shawshank Redemption, The      784       5  975430846      M
# 955070                   L.A. Confidential      784       5  975431260      M
# 955063                          Braveheart      784       5  975430335      M
# 955065  Star Wars: Episode IV - A New Hope      784       5  975430918      M
#
#         age  occupation    zip
# 955090   18           0  11040
# 955066   18           0  11040
# 955070   18           0  11040
# 955063   18           0  11040
# 955065   18           0  11040

# %% [markdown]
# *Lets merge the data of the two users with innner join using common data variables*

# %%
mutualintrestdata = dc.merge(dc1, on=["movie_id", "titleonly", "mean_rating", "count_rating"], how='inner')
mutualintrestdata = mutualintrestdata.sort_values(by=['mean_rating','count_rating'])

mutualintrestdata.head()
# Out:
#     movie_id                                title_x  \
# 37      3821  Nutty Professor II: The Klumps (2000)
# 34      3717              Gone in 60 Seconds (2000)
# 4        317               Santa Clause, The (1994)
# 9        497          Much Ado About Nothing (1993)
# 11       543    So I Married an Axe Murderer (1993)
#
#                      genres_x mean_rating count_rating year_x  \
# 37                     Comedy        3.78          248   2000
# 34               Action|Crime        3.78          584   2000
# 4   Children's|Comedy|Fantasy        3.78          641   1994
# 9              Comedy|Romance        3.78          667   1993
# 11    Comedy|Romance|Thriller        3.78          682   1993
#
#                          titleonly  user_id_x  rating_x  timestamp_x  ...  \
# 37  Nutty Professor II: The Klumps         44         3    978018699  ...
# 34              Gone in 60 Seconds         44         4    978018699  ...
# 4                Santa Clause, The         44         2   1004410334  ...
# 9           Much Ado About Nothing         44         5    978019688  ...
# 11    So I Married an Axe Murderer         44         4   1004409912  ...
#
#                                   title_y                   genres_y  year_y  \
# 37  Nutty Professor II: The Klumps (2000)                     Comedy    2000
# 34              Gone in 60 Seconds (2000)               Action|Crime    2000
# 4                Santa Clause, The (1994)  Children's|Comedy|Fantasy    1994
# 9           Much Ado About Nothing (1993)             Comedy|Romance    1993
# 11    So I Married an Axe Murderer (1993)    Comedy|Romance|Thriller    1993
#
#    user_id_y rating_y timestamp_y gender_y  age_y  occupation_y  zip_y
# 37       237        3   976761242        M     25             6  46835
# 34       237        3   976761328        M     25             6  46835
# 4        237        4   992129778        M     25             6  46835
# 9        237        3   976760795        M     25             6  46835
# 11       237        4   976762829        M     25             6  46835
#
# [5 rows x 24 columns]

# %% [markdown]
# *Now most liked movie by both individuals can be found with the above combined data with the help of index integers values through the reference with short title*

# %%
mutualintrestdata.iloc[-1]['titleonly']
# Out:
# 'Star Wars: Episode IV - A New Hope'
